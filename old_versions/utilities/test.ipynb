# %%
import pandas as pd
df = pd.read_csv("../dataset/cropped/crops.csv")
print(df[df["split"] == "train"]["label"].value_counts())
print(df[df["split"] == "test"]["label"].value_counts())
# Out:
# label
# green            5124
# fully_ripened    1328
# half_ripened     1316
# Name: count, dtype: int64
# label
# green            1777
# fully_ripened     540
# half_ripened      506
# Name: count, dtype: int64
